# %% [markdown]
# <a href="https://colab.research.google.com/github/juliavaz/Python/blob/master/aula_28_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''for a in range(3,5):
  for b in range(0,a):
    print(a*b)'''
# a --> 3, 4
# b --> 0, a-1

# for a, 1º a=3
#   for b entre 0 e 2, 1º b=0; print(0)
#   for b entre 0 e 2, 2º b=1; print(3)
#   for b entre 0 e 2, 3º b=2; print(6)
# for a, 2º a=4
#   for b entre 0 e 3, 1º b=0; print(0)
#   for b entre 0 e 3, 2º b=1; print(4)
#   for b entre 0 e 3, 3º b=2; print(8)
#   for b entre 0 e 3, 4º b=3; print(12)

'''lista = list(range(2,21))
print(lista)
for _ in lista:
  if _ % 2 == 0:
    print(_)
  elif _ % 3 ==0:
    print(_)
  else:
    pass'''

'''x=5
while x<7:
  print(x)
  x+=1'''  # x = x + 1
# Antes do while x = 5
# 5<7? Sim --> print(5); x=6
# 6<7? Sim --> print(6); x=7
# 7<7? Não

'''x=5
while True:
  print(x)
  x += 1 # x = x + 1
  if x==7:
    break'''
# Antes do while temos que x=5
# 1º print(5); x=6; 6==7? Não --> Não entra no if
# 2º print(6); x=7; 7==7? Sim --> Entra no if --> BREAK

# Faça um script que solicite a qde de alunos, o nome
# dos alunos, a nota dos alunos e imprima reprovado
# ou aprovado de acordo com a nota. O script também
# deverá solicitar uma nota válida caso a nota inserida
# for <0 ou >10
'''qde = ,(input('Insira a quantidade de alunos: '))
alunos = []
for _ in range(1, qde+1): # ex: qde = 3 -->  1, 2, 3
  novo_aluno = input('Insira o nome do aluno '+ str(_) +' : ')
  alunos.append(novo_aluno)
#print(alunos)
for _ in alunos:
  nota = float(input('Insira a nota do aluno '+ _ + ': '))
  if nota<0 or nota>10:
    while True:
      print('Nota INVÁLIDA, insira uma nota entre 0 e 10!')
      nota = float(input('Insira a nota do aluno '+ _ + ': '))
      if nota >= 0 and nota <= 10:
        break
  if nota < 5:
    print('Aluno ' + _ + ' REPROVADO')
  else:
    print('Aluno ' + _ + ' APROVADO')'''

'''frase = 'abcdefghijk'
for x,y in enumerate(frase):
  print(x,y)'''

'''lista = [5, 6, 8, 'carro', 'moto']
for x,y in enumerate(lista):
  print(x,y)'''

'''nomes = ['a1', 'a2', 'a3', 'a4']
notas = [9, 2, 5, 3]
faltas = [10, 0, 15, 20]
for x,y,z in zip(nomes,notas,faltas):
  print('O aluno ' + x + ' teve', z, 'faltas e nota:', y)'''

'''nomes = ['a1', 'a2', 'a3', 'a4']
notas = [9, 2, 5, 3]
x = list(zip(nomes,notas))
print(x)
print(x[1][1])'''

'''x = [2, 5, 9, 'a', 0, 'b']
print(3 in x)'''

'''frase = 'rio mississipi'
print(frase.count('r'))'''

'''x = [2, 5, 9, 'a', 0, 'b', 0, 2, 3, 9, 0]
print(x.count('c'))'''

'''dic1 = {'a':1, 34:98, 3:'w', True:False}
print(34 in dic1.keys())
print('a' in dic1.values())'''

'''lista = [85, 35, 102, 140, 5.6, 123.5, 51.7]
print(max(lista))
print(min(lista))'''

# ordenação randômica de uma lista já existente:
'''from random import shuffle
lista = [85, 35, 102, 140, 5.6, 123.5, 51.7]
shuffle(lista)
print(lista)'''

'''from random import randint
num_rand = randint(4,7)
print(num_rand)'''

# Calcule a probabilidade de uma moeda ter o valor
# cara. Simule em X (a definir) lançamentos
'''X = int(input('Insira a quantidade de lançamentos: '))
from random import randint
cara=0
coroa=0
for _ in range(0,X): # range 0 e 99999
  resultado = randint(0,1)
  if resultado == 0:
    cara += 1
  else:
    coroa +=1
print('Sairam', cara, 'caras. Probabilidade de cara =', round(cara/X,2))
print('Sairam', coroa, 'coroas. Probabilidade de coroa =', round(coroa/X,2))'''

'''import random
print(random.uniform(1,1.1))'''

# Criar uma lista com 10 posições contendo inteiros aleatórios entre 1 e 100:
'''from random import randint
lista = []
for _ in range(0,10):
  lista.append(randint(1,100))
print(lista)'''

# Criar uma lista com 10 float entre 0 e 1 e com 2 casas decimais:
'''import random
lista = []
for _ in range(0,10):
  lista.append(round(random.uniform(0,1),2))
print(lista)'''

'''cel = list(range(0,27,2))
print(cel)
far = []
for _ in cel:
  far.append(round((9/5)*_+32,2))
print(far)'''

'''cel = list(range(0,27,2))
far = [round((9/5)*_+32,2) for _ in cel]
print(far)'''

# Exercícios Básicos! Slides 22, 23, 24:
# Ex 1:
'''ano = int(input('Insira sua idade em anos: '))
mes = int(input('Insira quantos meses se passaram desde seu aniversário: '))
dia = int(input('Insira quantos dias se passaram nesse mes desde o dia do seu aniversário: '))
print('A sua idade em dias é', ano*365+mes*30+dia)'''

# Ex3:
'''saldo = 100
print('Seu saldo reajustado é', saldo*1.01)'''

# Ex4:
'''IPI = float(input('Insira o valor do IPI: '))
custo_p1 = float(input('Insira o valor da peça 1: '))
qde_p1 = float(input('Insira a quantidade de peças 1 a serem vendidas: '))
custo_p2 = float(input('Insira o valor da peça 2: '))
qde_p2 = float(input('Insira a quantidade de peças 2 a serem vendidas: '))
custo_total = (custo_p1*qde_p1 + custo_p2*qde_p2)*(IPI/100 + 1)
print('O valor a ser pago é: R$', round(custo_total,2))'''

# Ex 5:
'''sal_min = float(input('Insira o valor do salário mínimo: R$'))
sal_usu = float(input('Insira o valor do seu salári: R$'))
print('Você ganha', round(sal_usu/sal_min,2), 'salários mínimos')'''

# Ex 6:
num = int(input('Insira um número inteiro: '))
print('Antecessor:', num-1, '. Sucessor:', num+1)
